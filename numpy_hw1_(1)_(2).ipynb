# %% [markdown]
# # <a href="https://mipt-stats.gitlab.io/courses/ad_mipt.html">Phystech@DataScience</a>
# ## Задание 1
#
# **Правила, <font color="red">прочитайте внимательно</font>:**
#
# * Выполненную работу нужно отправить телеграм-боту `@miptstats_pds_bot`. Для начала работы с ботом каждый раз отправляйте `/start`. **Работы, присланные иным способом, не принимаются.**
# * Дедлайн см. в боте. После дедлайна работы не принимаются кроме случаев наличия уважительной причины.
# * Прислать нужно ноутбук в формате `ipynb`.
# * Выполнять задание необходимо полностью самостоятельно. **При обнаружении списывания все участники списывания будут сдавать устный зачет.**
# * Решения, размещенные на каких-либо интернет-ресурсах, не принимаются. Кроме того, публикация решения в открытом доступе может быть приравнена к предоставлении возможности списать.
# * Для выполнения задания используйте этот ноутбук в качестве основы, ничего не удаляя из него. Можно добавлять необходимое количество ячеек.
# * Комментарии к решению пишите в markdown-ячейках.
# * Выполнение задания (ход решения, выводы и пр.) должно быть осуществлено на русском языке.
# * Если код будет не понятен проверяющему, оценка может быть снижена.
# * Никакой код из данного задания при проверке запускаться не будет. *Если код студента не выполнен, недописан и т.д., то он не оценивается.*
#
# **Баллы за задание:**
#
# <b><font color="blue">Легкая часть</font></b> (достаточно на "хор"):
# * Задача 1 &mdash; 5 баллов
# * Задача 2 &mdash; 10 баллов
# * Задача 3 &mdash; 15 баллов
#
#
# <b><font color="orange">Сложная часть</font></b> (необходимо на "отл"):
# * Задача 4 &mdash; 15 баллов
# * Задача 5 &mdash; 25 баллов
#
#
# -----

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### <font color="blue"><i>Легкая часть</i></font>

# %% [markdown]
# ### Задача 1
# Создайте матрицу 10x10 по правилу:
# - если сумма индексов элемента четна - присваиваем элементу значение 0
# - если сумма индексов элемента нечетна - присваиваем элементу значение 1
#
# Исаользуйте numpy. Визуализируйте полученную матрицу с помощью `plt.imshow()`.

# %%
a = np.zeros((10, 10))
for i in range(10):
  for j in range(10):
    if (i + j) % 2 != 0:
      a[i, j] = 1
plt.imshow(a);

# %% [markdown]
# ### Задача 2
# 1) Создайте матрицу 10х10, каждый элемент которой равен сумме индексов этого элемента.  Используйте numpy.  Визуализируйте с помощью `plt.imshow()`.

# %%
a = np.zeros((10, 10))
for i in range(10):
  for j in range(10):
      a[i, j] = i + j
plt.imshow(a);# Ваш код здесь

# %% [markdown]
# 2. Повторите свое решение <font color='red'> без использования циклов <font color='black'> (list comrehension использовать не запрещено).

# %%
a = np.zeros((10, 10))
a = [[i + j for j in range(9)] for i in range(9)]
plt.imshow(a);# Ваш код здесь

# %% [markdown]
# ### Задача 3
# Изобразите график параметрически заданной функции. Переменные необходимо задавать с помощью Numpy.
#
# $$ x=\alpha\times\left(\cos t+\frac{cos(\beta t)}{\beta}\right)$$
#
# $$y=\alpha\times\left(\sin t−\frac{sin(\beta t)}{\beta}\right)$$
#
# $$t∈[0;20π]$$
#
# 1. Реализуйте функции $x(t, \alpha, \beta)$ и $y(t, \alpha, \beta)$

# %%
t = np.linspace(0, 20 * np.pi, 50)
def x(t, a, b):
  x = a*(np.cos(t) + (np.cos(b*t))/b)
  return x# Ваш код здесь
def y(t, a, b):
  y = a*(np.sin(t) - (np.sin(b*t))/b)
  return y# Ваш код здесь

# %% [markdown]
# 2. Постройте график в осях $x$ и $y$ при $\alpha=4$ и $\beta=1.1$. Подпишите оси.

# %%
a = 4
b = 1.1
plt.figure(figsize=(4,4))
plt.plot(x(t, a, b), y(t, a, b))
plt.xlabel('x')
plt.ylabel('y')
plt.show()# Ваш код здесь

# %% [markdown]
# 3. Постройте графики для различных значений $\alpha$ и $\beta$.
# - $\alpha$ : [2, 4, 6, 8, 10]
# - $\beta$ : [1.2, 1.8, 2, 5, 10]
#
# У вас должна получиться сетка 5х5 графиков. На каждом графике укажите параметры $\alpha$ и $\beta$.

# %%
a = np.linspace(2, 10, 5)
b = [1.2, 1.8, 2, 5, 10]
fig, ax = plt.subplots(5, 5, figsize=(10, 10))
for i in range(5):
    for j in range(5):
        ax[i][j].plot(x(t, a[j], b[i]), y(t, a[j], b[i]), label = f'a = {a[j]}, b = {b[i]}')
        plt.xlabel('x')
        plt.ylabel('y')
        ax[i][j].legend()
plt.show()# Ваш код здесь

# %% [markdown]
# ### Задача 4
#
# Выполните все шаги, описанные ниже и визуализируйте полученный результат. Результатом является квадратная матрица.

# %%
a1 = np.zeros((3, 3))# Создать матрицу а1 размера 3 x 3 из нулей

a1[1, 1] = 1# Приравнять единице значения матрицы a1 по координатам (1, 1)

a2 = a1# Скопировать матрицу a1 в матрицу a2

a3 = np.concatenate((a1, a2), axis = 1)# Конкатенировать матрицы a1 и a2 по оси 1 и записать результат в матрицу a3

a4 = np.zeros(6)# Создать матрицу a4 размера 6 из нулей

a4 = np.ones(6)
a4[0] = 0
a4[5] = 0# Запонить всё единицами кроме нулевой и последней ячейки в матрице a4

a5 = np.zeros(6)# Создать матрицу a5 размера 6 из нулей

a5[2] = 1
a5[3] = 1# Заполнить ячейки с координатами 2 и 3 единицами в матрице а5

ab = np.vstack([a4, a5])#Объединить матрицы а4 и а5 по нулевой оси и записать результат в матрицу 


a7 = np.zeros(6)# Создать матрицу а7 размера 6 из нулей

a8 = np.vstack((ab, a7))# Конкатенировать матрицы а6 и а7 по нулевой оси и записать результат в матрицу а8

a9 = np.vstack([a3, a8])# Конкатенировать матрицы а3 и а8 по нулевой оси и записать результат в матрицу а9

plt.imshow(a9);# Визуализировать матрицу а9 с помощью plt.imshow()

# %% [markdown]
# ### Задача 5
# Напишите функцию, реализующую матричное умножение. При вычислении разрешается создавать
# объекты размерности три.
#
# Запрещается пользоваться функциями, реализующими матричное
# умножение ( numpy.dot , операция @ , операция умножения в классе numpy.matrix ). Разрешено
# пользоваться только простыми векторно-арифметическими операциями над numpy.array , а также
# преобразованиями осей.
#
#  *Комментарий*: При рациональном подходе ваше решение займет 1 строчку

# %%
def matrix_multiplication(A, B):
  R = [[ sum(a*b for a, b in zip(A[0, :], B[:, 0])) for B[:, 0] in zip(*B)] for A[0, :] in A]
  return R

# %% [markdown]
# Проверьте правильность реализации на случайных матрицах. Должен получится ноль.

# %%
A = np.random.rand(10, 20)
B = np.random.rand(20, 30)
np.abs(matrix_multiplication(A, B) - A @ B).sum()
# Out:
# 58.45033658948285

# %% [markdown]
# Сравните время работы вашей функции и любой из реализаций в numpy.
